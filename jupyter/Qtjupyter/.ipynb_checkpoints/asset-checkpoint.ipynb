# %%
using CSV
using DataFrames

# %%
function data_from_csv(Stock)
    df = CSV.read("data\\"* Stock * ".csv",DataFrame)
    
    return df
end
data_from_csv("AAPL")
# Out:
# 9973×7 DataFrame
#   Row │ date        volume     open        high        low         close       ⋯
#       │ Date        Int64      Float64     Float64     Float64     Float64     ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ 2020-07-02   28484300  367.85      370.47      363.64      364.11      ⋯
#     2 │ 2020-07-01   27684300  365.12      367.36      363.91      364.11
#     3 │ 2020-06-30   35055800  360.08      365.98      360.0       364.8
#     4 │ 2020-06-29   32661500  353.25      362.17      351.28      361.78
#     5 │ 2020-06-26   51314200  364.41      365.32      353.02      353.63      ⋯
#     6 │ 2020-06-25   34380600  360.7       365.0       357.57      364.84
#     7 │ 2020-06-24   48155800  365.0       368.79      358.52      360.06
#     8 │ 2020-06-23   53038900  364.0       372.38      362.27      366.53
#     9 │ 2020-06-22   33861300  351.34      359.46      351.15      358.87      ⋯
# ...
